# %% [markdown]
# **Обзор тенденций прошлых лет (по данным ежегодных исследований РУССОФТ: https://russoft.org/russoft-analytics/)**

# %%
import pandas as pd

# %%
# Наиболее популярные инструменты разработки:

ide = pd.DataFrame({'2008': [46, 19, 10, None, None, None, None, None],
                    '2009': [64, 25, 5, None, None, None, None, None],
                    '2010': [60, 19, 3, None, None, None, None, None], 
                    '2011': [62, 6, 8, None, None, None, None, None],
                    '2012': [45, 16, 9, None, None, None, None, None],
                    '2013': [36, 15, 4, 2, None, 3, None, None],
                    '2014': [53, 34, 14, 14, None, 8, 15, None],
                    '2015': [49, 12, 9, 6, 2, 0, 24, 24],
                    '2016': [57, 25, 21, 15, 10, 7, 20, 16],
                    '2017': [55, 28,26, 18, 12, 10, 16, 9],
                    '2018': [57, 26, 26, 27, 21, 18, 15, 11],
                    '2019': [58, 43, 33, 26, 24, 18, 21, 10]
                   },
                    index=['MS Visual Studio',
                           'Eclipse',
                           'Intellij IDEA',
                           'Xcode',
                           'WebStorm',
                           'NetBeans',
                           'Other',
                           'Do not use']
                    )

# %%
ide.head(8)
# Out:
#                   2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# MS Visual Studio  46.0  64.0  60.0  62.0  45.0  36.0  53.0    49    57    55
# Eclipse           19.0  25.0  19.0   6.0  16.0  15.0  34.0    12    25    28
# Intellij IDEA     10.0   5.0   3.0   8.0   9.0   4.0  14.0     9    21    26
# Xcode              NaN   NaN   NaN   NaN   NaN   2.0  14.0     6    15    18
# WebStorm           NaN   NaN   NaN   NaN   NaN   NaN   NaN     2    10    12
# NetBeans           NaN   NaN   NaN   NaN   NaN   3.0   8.0     0     7    10
# Other              NaN   NaN   NaN   NaN   NaN   NaN  15.0    24    20    16
# Do not use         NaN   NaN   NaN   NaN   NaN   NaN   NaN    24    16     9
#
#                   2018  2019
# MS Visual Studio    57    58
# Eclipse             26    43
# Intellij IDEA       26    33
# Xcode               27    26
# WebStorm            21    24
# NetBeans            18    18
# Other               15    21
# Do not use          11    10

# %%
ide.plot(kind='bar',
         figsize=(15, 5), 
         title='Наиболее популярные инструменты разработки')
# Out:
# <AxesSubplot:title={'center':'Наиболее популярные инструменты разработки'}>

# %%
# Top-10 используемых операционных систем:

os = pd.DataFrame({'2008': [97, 64, None, None, 26, 25, 41, 26, None, None],
                   '2009': [94, 54, None, None, 9, 7, 17, 16, None, None],
                   '2010': [93, 54, 6, None, 15, 9, 16, 15, None, None], 
                   '2011': [96, 59, 4, None, 19, 9, 15, 19, None, None],
                   '2012': [94, 60, 37, 28, 32, 13, 23, 19, 19, None],
                   '2013': [88, 65, 33, 24, 31, 10, 17, 14, 19, None],
                   '2014': [92, 51, 43, 34, 33, 14, 15, 15, 22, None],
                   '2015': [87, 59, 36, 29, 32, 13, 23, 11, 23, None],
                   '2016': [93, 60, 43, 35, 33, 11, 19, 16, 21, 4],
                   '2017': [84, 57, 39, 36, 37, 11, 20, 7, 15, 7],
                   '2018': [89, 59, 53, 49, 48, 19, 14, 13, 12, 5],
                   '2019': [88, 72, 58, 49, 48, 22, 18, 13, 13, 8],
                   '2020': [74, 76, 60, 50, 31, 8, 2, 3, 2, 6]
                   },
                    index=['MS Windows',
                           'GNU Linux family',
                           'Android',
                           'iOS',
                           'Mac OS',
                           'Open/Free/NetBSD',
                           'MS Windows Mobile',
                           'Oracle (Sun) Solaris',
                           'MS Windows Phone',
                           'Tizen']
                    )

# %%
os.head(10)
# Out:
#                       2008  2009  2010  2011  2012  2013  2014  2015  2016  \
# MS Windows            97.0  94.0  93.0  96.0  94.0  88.0  92.0  87.0    93
# GNU Linux family      64.0  54.0  54.0  59.0  60.0  65.0  51.0  59.0    60
# Android                NaN   NaN   6.0   4.0  37.0  33.0  43.0  36.0    43
# iOS                    NaN   NaN   NaN   NaN  28.0  24.0  34.0  29.0    35
# Mac OS                26.0   9.0  15.0  19.0  32.0  31.0  33.0  32.0    33
# Open/Free/NetBSD      25.0   7.0   9.0   9.0  13.0  10.0  14.0  13.0    11
# MS Windows Mobile     41.0  17.0  16.0  15.0  23.0  17.0  15.0  23.0    19
# Oracle (Sun) Solaris  26.0  16.0  15.0  19.0  19.0  14.0  15.0  11.0    16
# MS Windows Phone       NaN   NaN   NaN   NaN  19.0  19.0  22.0  23.0    21
# Tizen                  NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN     4
#
#                       2017  2018  2019  2020
# MS Windows              84    89    88    74
# GNU Linux family        57    59    72    76
# ...

# %%
os.plot(kind='bar',
        figsize=(15, 5), 
        title='Top-10 используемых операционных систем')
# Out:
# <AxesSubplot:title={'center':'Top-10 используемых операционных систем'}>

# %%
# Основные используемые СУБД, % от всех опрошенных компаний:

subd = pd.DataFrame({'2008': [68, 31, 82, 69, 8, 49, 19, None, 33, 27, 13, 18, 13, 5, 9, 18, 12, None],
                    '2009': [35.8, 11.0, 66.1, 48.6, 5.5, 14.7, 11.0, None, 8.3, 9.2, 3.7, 5.5, 6.4, 2.8, 4.6, 7.3, 1.8, None],
                    '2010': [47, 17, 63, 49, 9, 19, 11, None, 13, 7, 6, 7, 6, None, 6, 9, 4, 13], 
                    '2011': [40, 15, 74, 55, 5, 9, 9, None, 14, 5, 3, 5, 6, None, 5, 7, 3, 8],
                    '2012': [59, 26, 70, 51, 12, 19, 10, None, 9, 5, 3, 7, 5, None, 7, 7, 3, 7],
                    '2013': [56, 30, 66, 47, 10, 17, 13, None, 10, 5, 6, 7, 6, None, 5, 10, 2, 8],
                    '2014': [56, 28, 70, 45, 19, 18, 16, None, 12, 7, 8, 6, 6, None, 5, 6, 4, 10],
                    '2015': [54, 28, 67, 39, 12, 19, 15, None, 12, 2, 6, 4, 3, None, 3, 6, 3, 9],
                    '2016': [42, 33, 59, 36, 10, 17, 11, None, 8, 2, 2, 1, 2, None, 5, 3, 1, 5],
                    '2017': [53, 36, 61, 37, 19, 18, 11, None, 8, 4, 3, 3, 2, 3, 2, 3, 2, 9],
                    '2018': [61, 51, 67, 40, 25, 16, 14, 6, 7, 6, 5, 6, 4, 4, 6, 7, 5, 14],
                    '2019': [72, 66, 62, 41, 35, 23, 13, 10, 9, 7, 7, 6, 6, 6, 5, 5, 4, 13],
                    '2020': [54, 79, 58, 40, 29, 8, 13, 35, 8, 0, 4, 4, 4, 4, 6, 4, 2, 8]
                   },
                    index=['MySQL',
                           'PostgreSQL',
                           'MS SQL',
                           'Oracle',
                           'SQLite',
                           'MS Access',
                           'Firebird',
                           'MongoDB',
                           'IBM DB2',
                           'MSDE',
                           'Sybase ASE',
                           'IBM Informix',
                           'Sybase ASA',
                           'Линтер',
                           'SAP DB',
                           'InterBase',
                           'Paradox',
                           'Другие']
                    )

# %%
subd.head(18)
# Out:
#               2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  \
# MySQL         68.0  35.8  47.0  40.0  59.0  56.0  56.0  54.0  42.0  53.0
# PostgreSQL    31.0  11.0  17.0  15.0  26.0  30.0  28.0  28.0  33.0  36.0
# MS SQL        82.0  66.1  63.0  74.0  70.0  66.0  70.0  67.0  59.0  61.0
# Oracle        69.0  48.6  49.0  55.0  51.0  47.0  45.0  39.0  36.0  37.0
# SQLite         8.0   5.5   9.0   5.0  12.0  10.0  19.0  12.0  10.0  19.0
# MS Access     49.0  14.7  19.0   9.0  19.0  17.0  18.0  19.0  17.0  18.0
# Firebird      19.0  11.0  11.0   9.0  10.0  13.0  16.0  15.0  11.0  11.0
# MongoDB        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# IBM DB2       33.0   8.3  13.0  14.0   9.0  10.0  12.0  12.0   8.0   8.0
# MSDE          27.0   9.2   7.0   5.0   5.0   5.0   7.0   2.0   2.0   4.0
# Sybase ASE    13.0   3.7   6.0   3.0   3.0   6.0   8.0   6.0   2.0   3.0
# IBM Informix  18.0   5.5   7.0   5.0   7.0   7.0   6.0   4.0   1.0   3.0
# ...

# %%
subd.plot(kind='bar',
        figsize=(22, 5), 
        title='Основные используемые СУБД, % от всех опрошенных компаний')
# Out:
# <AxesSubplot:title={'center':'Основные используемые СУБД, % от всех опрошенных компаний'}>

# %%
# Языки программирования, используемые в качестве основных, % опрошенных компаний:

main_languages = pd.DataFrame({'2008': [38, 33, None, 13, 48, None, 13, 11, 4],
                    '2009': [21.1, 36, None, 5.8, 17.5, None, 18.4, 1.9, 0],
                    '2010': [22, 46, None, 8, 21, None, 18, 3, 2], 
                    '2011': [20, 38, None, 9, 24, None, 9, 2, 1],
                    '2012': [30, 36, None, 9, 41, None, 3, 5, 2],
                    '2013': [17, 17, 17, 9, 9, 17, 8, None, None],
                    '2014': [17, 17, 17, 9, 9, 17, 8, None, None],
                    '2015': [22, 26, 16, 6, 6, 12, 7, None, None],
                    '2016': [17, 26, 20, 5, 8, 8, 11, None, None],
                    '2017': [15, 18, 19, 5, 2, 15, 4, None, None],
                    '2018': [14, 19, 15, 12, 8, 4, 6, None, None],
                    '2019': [24, 17, 13, 13, 4, 4, 3, None, None],
                   },
                    index=['Java/J2EE',
                           'C/C++',
                           'C#',
                           'PHP',
                           '.NET',
                           'C',
                           'Delphi',
                           'PL/SQL',
                           'Perl']
                    )

# %%
main_languages.head(9)
# Out:
#            2008  2009  2010  2011  2012  2013  2014  2015  2016  2017  2018  \
# Java/J2EE  38.0  21.1  22.0  20.0  30.0  17.0  17.0  22.0  17.0  15.0  14.0
# C/C++      33.0  36.0  46.0  38.0  36.0  17.0  17.0  26.0  26.0  18.0  19.0
# C#          NaN   NaN   NaN   NaN   NaN  17.0  17.0  16.0  20.0  19.0  15.0
# PHP        13.0   5.8   8.0   9.0   9.0   9.0   9.0   6.0   5.0   5.0  12.0
# .NET       48.0  17.5  21.0  24.0  41.0   9.0   9.0   6.0   8.0   2.0   8.0
# C           NaN   NaN   NaN   NaN   NaN  17.0  17.0  12.0   8.0  15.0   4.0
# Delphi     13.0  18.4  18.0   9.0   3.0   8.0   8.0   7.0  11.0   4.0   6.0
# PL/SQL     11.0   1.9   3.0   2.0   5.0   NaN   NaN   NaN   NaN   NaN   NaN
# Perl        4.0   0.0   2.0   1.0   2.0   NaN   NaN   NaN   NaN   NaN   NaN
#
#            2019
# Java/J2EE  24.0
# C/C++      17.0
# C#         13.0
# PHP        13.0
# .NET        4.0
# C           4.0
# Delphi      3.0
# PL/SQL      NaN
# Perl        NaN

# %%
main_languages.plot(kind='bar',
                    figsize=(15, 5), 
                    title='Языки программирования, используемые в качестве основных, % опрошенных компаний')
# Out:
# <AxesSubplot:title={'center':'Языки программирования, используемые в качестве основных, % опрошенных компаний'}>

# %%
# Неосновные языки программирования, применяемые в ряде проектов, % опрошенных компаний: 

minor_languages = pd.DataFrame({'2014': [None, 39, 23, 30, 25, 14, 10, 5, 7, 3, None, None, None, 4, 5, 3, None, 4, None, None, None],
                                '2015': [None, 44, 18, 25, 21, 24, 16, 7, 4, 8, None, None, None, 4, 5, 4, None, 4, None, None, None],
                                '2016': [29, 40, 26, 34, 26, 24, 19, 4, 10, 5, None, None, None, 3, 2, 4, None, 3, None, None, None],
                                '2017': [34, 46, 29, 41, 32, 22, 23, 7, 14, 7, None, 3, None, 1, 2, 1, None, 3, None, None, None],
                                '2018': [46, 49, 37, 40, 36, 33, 26, 11, 17, 6, 4, 6, 3, 4, 3, 2, 2, 2, 2, 2, 1],
                                '2019': [50, 47, 47, 44, 42, 35, 30, 22, 21, 15, 7, 4, 4, 3, 3, 3, 2, 1, 1, 1, 1],
                   },
                    index=['HTML5',
                           'Java',
                           'PHP',
                           'C++',
                           'C#',
                           '.Net',
                           'C',
                           'Javascript',
                           'Delphi',
                           'Python',
                           'Kotlin',
                           'Swift',
                           'Golang (Go)',
                           'Ruby',
                           'Objective C',
                           'SQL',
                           'Scala',
                           'Perl',
                           'CSS3',
                           'Erlang',
                           'Assembler'
                          ]
                )

# %%
minor_languages.head(21)
# Out:
#              2014  2015  2016  2017  2018  2019
# HTML5         NaN   NaN  29.0  34.0    46    50
# Java         39.0  44.0  40.0  46.0    49    47
# PHP          23.0  18.0  26.0  29.0    37    47
# C++          30.0  25.0  34.0  41.0    40    44
# C#           25.0  21.0  26.0  32.0    36    42
# .Net         14.0  24.0  24.0  22.0    33    35
# C            10.0  16.0  19.0  23.0    26    30
# Javascript    5.0   7.0   4.0   7.0    11    22
# Delphi        7.0   4.0  10.0  14.0    17    21
# Python        3.0   8.0   5.0   7.0     6    15
# Kotlin        NaN   NaN   NaN   NaN     4     7
# Swift         NaN   NaN   NaN   3.0     6     4
# Golang (Go)   NaN   NaN   NaN   NaN     3     4
# Ruby          4.0   4.0   3.0   1.0     4     3
# Objective C   5.0   5.0   2.0   2.0     3     3
# SQL           3.0   4.0   4.0   1.0     2     3
# Scala         NaN   NaN   NaN   NaN     2     2
# Perl          4.0   4.0   3.0   3.0     2     1
# CSS3          NaN   NaN   NaN   NaN     2     1
# ...

# %%
minor_languages.plot(kind='bar',
                    figsize=(22, 5), 
                    title='Неосновные языки программирования, применяемые в ряде проектов, % опрошенных компаний')
# Out:
# <AxesSubplot:title={'center':'Неосновные языки программирования, применяемые в ряде проектов, % опрошенных компаний'}>
